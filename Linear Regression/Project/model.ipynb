# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Coding\Machine_Learning\Machine Learning Coding\Linear Regression\Project\Dataset\repo_metadata.csv")

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 203917 entries, 0 to 203916
# Data columns (total 25 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   owner                     203917 non-null  str
#  1   name                      203915 non-null  str
#  2   stars                     203917 non-null  int64
#  3   forks                     203917 non-null  int64
#  4   watchers                  203917 non-null  int64
#  5   isFork                    203917 non-null  bool
#  6   isArchived                203917 non-null  bool
#  7   languages                 203917 non-null  str
#  8   languageCount             203917 non-null  int64
#  9   topics                    203917 non-null  str
#  10  topicCount                203917 non-null  int64
#  11  diskUsageKb               203917 non-null  int64
#  12  pullRequests              203917 non-null  int64
#  13  issues                    203917 non-null  int64
# ...

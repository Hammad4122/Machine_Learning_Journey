# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Coding\Machine_Learning\Machine Learning Coding\Linear Regression\Project\Dataset\repos.csv")

# %%
df.head(2)
# Out:
#              owner              name   stars  forks  watchers  isFork  \
# 0     freeCodeCamp      freeCodeCamp  426893  41377      8588   False
# 1  codecrafters-io  build-your-own-x  415801  38976      6247   False
#
#    isArchived                                          languages  \
# 0       False  [{'name': 'TypeScript', 'size': 2843131}, {'na...
# 1       False              [{'name': 'Markdown', 'size': 46108}]
#
#    languageCount                                             topics  ...  \
# 0              6  [{'name': 'learn-to-code', 'stars': 480}, {'na...  ...
# 1              1  [{'name': 'programming', 'stars': 1849}, {'nam...  ...
#
#    primaryLanguage             createdAt              pushedAt  \
# 0       TypeScript  2014-12-24T17:49:19Z  2025-08-31T09:33:14Z
# 1         Markdown  2018-05-09T12:03:18Z  2025-08-29T00:08:20Z
#
#    defaultBranchCommitCount                                  license  \
# ...

# %%
df.columns
# Out:
# Index(['owner', 'name', 'stars', 'forks', 'watchers', 'isFork', 'isArchived',
#        'languages', 'languageCount', 'topics', 'topicCount', 'diskUsageKb',
#        'pullRequests', 'issues', 'description', 'primaryLanguage', 'createdAt',
#        'pushedAt', 'defaultBranchCommitCount', 'license',
#        'assignableUserCount', 'codeOfConduct', 'forkingAllowed',
#        'nameWithOwner', 'parent'],
#       dtype='str')

# %%
df['name'] = df['name'].fillna("Unknown").astype(str)
plt.bar(df['name'], df['stars'])
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
# Reading data
df = pd.read_csv(r"C:\Coding\Machine_Learning\Machine Learning Coding\Multiple Linear Regression\Practice Problems\Closed Form\Dataset\multiple_linear_regression_dataset.csv")
df.head()
# Out:
#    age  experience  income
# 0   25           1   30450
# 1   30           3   35670
# 2   47           2   31580
# 3   32           5   40130
# 4   43          10   47830

# %%
X = np.matrix([1],df[['age','experience']])
X
# Out:
# matrix([[25,  1],
#         [30,  3],
#         [47,  2],
#         [32,  5],
#         [43, 10],
#         [51,  7],
#         [28,  5],
#         [33,  4],
#         [37,  5],
#         [39,  8],
#         [29,  1],
#         [47,  9],
#         [54,  5],
#         [51,  4],
#         [44, 12],
#         [41,  6],
#         [58, 17],
#         [23,  1],
#         [44,  9],
#         [37, 10]])
